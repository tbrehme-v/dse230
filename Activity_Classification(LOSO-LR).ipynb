# %% [markdown]
# ## Note: This notebook has a very long execution time (~25 minutes)

# %%
# !pip install --upgrade dask[complete] matplotlib seaborn pandas numpy scikit-learn

# %%
import dask
from dask import delayed, compute
import dask.dataframe as dd
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

# %%
# Load Datasets
path = "/home/work/Final/"
files = [
    "features_watch_a.csv",
    "features_watch_g.csv",
    "features_phone_a.csv",
    "features_phone_g.csv"
]

# %%
def run_logreg_loso(df, label_enc):
    subject_ids = df['sub_id'].unique()
    n_classes = len(label_enc.classes_)
    
    drop_cols = ['sub_id', 'group_id', 'activity', 'activity_encoded']
    X_all = df.drop(columns=drop_cols)
    y_all = df['activity_encoded']
    
    @delayed
    def run_loso_fold(test_sub):
        train_mask = df['sub_id'] != test_sub
        test_mask = df['sub_id'] == test_sub

        X_train = X_all.loc[train_mask]
        y_train = y_all.loc[train_mask]
        X_test = X_all.loc[test_mask]
        y_test = y_all.loc[test_mask]

        scaler = StandardScaler()
        X_train_scaled = scaler.fit_transform(X_train)
        X_test_scaled = scaler.transform(X_test)

        logreg = LogisticRegression(max_iter=500, solver='lbfgs', random_state=42)
        logreg.fit(X_train_scaled, y_train)

        y_train_pred = logreg.predict(X_train_scaled)
        y_test_pred = logreg.predict(X_test_scaled)

        train_acc = accuracy_score(y_train, y_train_pred)
        test_acc = accuracy_score(y_test, y_test_pred)

        cm = confusion_matrix(y_test, y_test_pred, labels=range(n_classes))
        report = classification_report(y_test, y_test_pred, output_dict=True, zero_division=0)
        feature_importances = np.abs(logreg.coef_).mean(axis=0)  # mean abs coef across classes

        return train_acc, test_acc, cm, report, feature_importances

    results = [run_loso_fold(test_sub) for test_sub in subject_ids]
    train_accs, test_accs, cms, reports, feature_imps = zip(*compute(*results))

    avg_train_acc = np.mean(train_accs)
    avg_test_acc = np.mean(test_accs)
    conf_matrix_sum = np.sum(cms, axis=0)
    avg_feature_importances = np.mean(feature_imps, axis=0)

    conf_matrix_avg = conf_matrix_sum / conf_matrix_sum.sum(axis=1, keepdims=True)

    def average_classification_reports(reports):
        keys = list(reports[0].keys())
        avg_report = {}
        all_class_labels = set()
        for r in reports:
            all_class_labels.update([k for k in r.keys() if k not in ['accuracy', 'macro avg', 'weighted avg']])
        all_class_labels = sorted(all_class_labels, key=lambda x: (not x.isdigit(), x))
        for k in keys:
            if k == 'accuracy':
                avg_report[k] = np.mean([r.get(k, 0) for r in reports])
            elif isinstance(reports[0][k], dict):
                avg_report[k] = {}
                if k in all_class_labels or k in ['macro avg', 'weighted avg']:
                    metrics = set()
                    for r in reports:
                        if k in r:
                            metrics.update(r[k].keys())
                    for metric in metrics:
                        vals = [r[k][metric] for r in reports if k in r and metric in r[k]]
                        avg_report[k][metric] = np.mean(vals) if vals else 0
            else:
                avg_report[k] = np.mean([r.get(k, 0) for r in reports])
        for class_label in all_class_labels:
            if class_label not in avg_report:
                avg_report[class_label] = {'precision': 0, 'recall': 0, 'f1-score': 0, 'support': 0}
        return avg_report

    avg_report = average_classification_reports(reports)

    return avg_train_acc, avg_test_acc, conf_matrix_sum, conf_matrix_avg, avg_report, avg_feature_importances, X_all.columns, label_enc.classes_

summary_results = []

for file in files:
    print(f"\nProcessing {file} ...")
    df_dask = dd.read_csv(path + file)
    df = df_dask.compute()

    label_enc = LabelEncoder()
    df['activity_encoded'] = label_enc.fit_transform(df['activity'])

    (avg_train_acc, avg_test_acc, conf_matrix_sum, conf_matrix_avg, avg_report, 
     avg_feature_importances, feature_names, class_names) = run_logreg_loso(df, label_enc)

    print(f"Average Train Accuracy: {avg_train_acc:.3f}")
    print(f"Average Test Accuracy:  {avg_test_acc:.3f}")
    print("\nAverage Confusion Matrix (Normalized by True Class):")
    print(conf_matrix_avg)
    print("\nAverage Confusion Matrix (Raw counts):")
    print(conf_matrix_sum)

    plt.figure(figsize=(10, 8))
    sns.heatmap(conf_matrix_sum, annot=True, fmt='d', xticklabels=class_names, yticklabels=class_names)
    plt.title(f"Confusion Matrix (Raw Counts) - {file}")
    plt.xlabel("Predicted Label")
    plt.ylabel("True Label")
    plt.tight_layout()
    plt.show()

    plt.figure(figsize=(10, 8))
    sns.heatmap(conf_matrix_avg, annot=True, fmt='.2f', xticklabels=class_names, yticklabels=class_names)
    plt.title(f"Confusion Matrix (Normalized by True Class) - {file}")
    plt.xlabel("Predicted Label")
    plt.ylabel("True Label")
    plt.tight_layout()
    plt.show()

    print("\nAverage Classification Report (per-class precision, recall, f1-score):")
    for label_idx, label_name in enumerate(class_names):
        pr = avg_report[str(label_idx)]
        print(f"{label_name}: Precision: {pr['precision']:.3f}, Recall: {pr['recall']:.3f}, F1-score: {pr['f1-score']:.3f}")

    print(f"\nOverall Accuracy: {avg_report['accuracy']:.3f}")

    summary_results.append({
        "Dataset": file,
        "Train Accuracy": avg_train_acc,
        "Test Accuracy": avg_test_acc
    })

    # Feature importance plot
    indices = np.argsort(avg_feature_importances)[::-1]
    top_n = min(45, len(feature_names))

    plt.figure(figsize=(12, 6))
    plt.title(f"Average Feature Importances (Logistic Regression LOSO) - {file}")
    plt.bar(range(top_n), avg_feature_importances[indices[:top_n]], align='center')
    plt.xticks(range(top_n), feature_names[indices[:top_n]], rotation=90)
    plt.tight_layout()
    plt.show()
# Out:
# Processing features_watch_a.csv ...
# Average Train Accuracy: 0.668
# Average Test Accuracy:  0.648
#
# Average Confusion Matrix (Normalized by True Class):
# [[6.13549618e-01 2.48091603e-02 1.29770992e-01 0.00000000e+00
#   0.00000000e+00 9.54198473e-04 7.63358779e-03 0.00000000e+00
#   0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#   8.87404580e-02 8.30152672e-02 2.48091603e-02 0.00000000e+00
#   2.86259542e-03 2.38549618e-02]
#  [1.75609756e-02 9.38536585e-01 6.82926829e-03 0.00000000e+00
#   0.00000000e+00 0.00000000e+00 9.75609756e-04 9.75609756e-04
#   0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#   9.75609756e-04 1.85365854e-02 3.90243902e-03 0.00000000e+00
#   8.78048780e-03 2.92682927e-03]
#  [1.26937984e-01 5.81395349e-03 5.51356589e-01 9.68992248e-04
#   1.93798450e-03 0.00000000e+00 1.25968992e-02 0.00000000e+00
#   1.16279070e-02 0.00000000e+00 9.68992248e-04 0.00000000e+00
#   1.56007752e-01 4.84496124e-02 3.19767442e-02 0.00000000e+00
#   3.87596899e-03 4.74806202e-02]
#  [0.00000000e+00 0.00000000e+00 0.00000000e+00
#  [  1   0   7  68 114   7  25  68 195  64 181 198  13  24   1   4   3  40]
#  [111   8 113   1   6   0  27   6   4   2   2   2 596 114  36   0   9   6]
#  [ 12   8  15   1  11   2   3  11   1  13   0   0  80 768  35   4  40  42]
#  [  7  12  33   0   5   1  18   7   0   5   1   1  81  91 704   1  32  59]
#  [  2   0   1  43 111 121  33   6  21  28  19  17   5  19   6 619  17   4]
#  [ 12  13   5  20  72  22  90   0   1   3   9   6  10   2  31  36 707   1]
#  [  7   0  36   1  16   0  15  34  10  27   6   6   8  47  11  11  11 806]]
# Average Classification Report (per-class precision, recall, f1-score):
# A: Precision: 0.707, Recall: 0.664, F1-score: 0.659
# B: Precision: 0.950, Recall: 0.941, F1-score: 0.931
# C: Precision: 0.592, Recall: 0.588, F1-score: 0.571
# D: Precision: 0.642, Recall: 0.607, F1-score: 0.590
# E: Precision: 0.643, Recall: 0.606, F1-score: 0.611
# F: Precision: 0.721, Recall: 0.728, F1-score: 0.699
# G: Precision: 0.750, Recall: 0.736, F1-score: 0.714
# H: Precision: 0.576, Recall: 0.543, F1-score: 0.525
# I: Precision: 0.462, Recall: 0.473, F1-score: 0.437
# J: Precision: 0.537, Recall: 0.553, F1-score: 0.511
# K: Precision: 0.563, Recall: 0.624, F1-score: 0.563
# L: Precision: 0.342, Recall: 0.213, F1-score: 0.248
# M: Precision: 0.652, Recall: 0.617, F1-score: 0.614
# O: Precision: 0.767, Recall: 0.808, F1-score: 0.769
# P: Precision: 0.768, Recall: 0.755, F1-score: 0.733
# Q: Precision: 0.664, Recall: 0.668, F1-score: 0.644
# R: Precision: 0.796, Recall: 0.770, F1-score: 0.761
# S: Precision: 0.755, Recall: 0.824, F1-score: 0.769
#
# Overall Accuracy: 0.648
# Processing features_watch_g.csv ...
# Average Train Accuracy: 0.642
# Average Test Accuracy:  0.591
#
# Average Confusion Matrix (Normalized by True Class):
# [[0.67505241 0.03459119 0.11111111 0.00419287 0.         0.00733753
#   0.01467505 0.         0.00524109 0.         0.         0.
#   0.09538784 0.00419287 0.00838574 0.00628931 0.00733753 0.02620545]
#  [0.00537634 0.85376344 0.01290323 0.00107527 0.         0.
#   0.         0.         0.00107527 0.         0.         0.
#   0.01612903 0.04301075 0.02473118 0.         0.03010753 0.01182796]
#  [0.17745536 0.01897321 0.40848214 0.00111607 0.00223214 0.
#   0.00334821 0.00892857 0.00446429 0.00446429 0.         0.00334821
#   0.24665179 0.03571429 0.00669643 0.         0.00334821 0.07477679]
#  [0.         0.00103734 0.00518672 0.53526971 0.14004149 0.0466805
#   0.00829876 0.02074689 0.01970954 0.03008299 0.07987552 0.0280083
#   0.01556017 0.00518672 0.00622407 0.02593361 0.00518672 0.02697095]
#  [0.         0.00104058 0.00520291 0.16233091 0.46097815 0.0301769
#   0.01873049 0.02081165 0.04578564 0.04266389 0.0842872  0.04994797
#   0.01456816 0.00208117 0.00208117 0.04266389 0.00312175 0.01352758]
#  [0.         0.         0.00107875 0.05285868 0.12081985 0.60625674
#  [   0    0    0   48  139   79  115  104  100  140  184   92    1   10
#      7   95   24   76]
#  [   4    0    2  125   99  104  189   91  103  182  184  116   13   14
#      5   82   36   42]
#  [  18    0    2  102  173   83   89   76  131  141  144   85    2   34
#     18   98   43   55]
#  [ 193   30  172    0    0    0    6    0    0    0    2    1  443  271
#    203    0    7   31]
#  [  54   11   63    1   40    3   26    1    0    0    3    4  220  376
#    198    1   27  298]
#  [  88   38   85    2   15    2   50    4    3    3    1    2  185  200
#    492    4   44  112]
#  [   0    0    1  122  173  160  160   42   98   61  150   63    1    8
#     11  154   31   32]
#  [  21    0    5   32   57   18  344   29   35   12   59   25   20   26
#     29   32  474   87]
#  [  17    0   22    4  108   12   80   48   28    8   18   21   20  207
#     47    6   51  595]]
# Average Classification Report (per-class precision, recall, f1-score):
# A: Precision: 0.476, Recall: 0.508, F1-score: 0.439
# B: Precision: 0.879, Recall: 0.867, F1-score: 0.854
# C: Precision: 0.545, Recall: 0.581, F1-score: 0.510
# D: Precision: 0.167, Recall: 0.141, F1-score: 0.122
# E: Precision: 0.447, Recall: 0.453, F1-score: 0.405
# F: Precision: 0.162, Recall: 0.127, F1-score: 0.118
# G: Precision: 0.319, Recall: 0.298, F1-score: 0.250
# H: Precision: 0.136, Recall: 0.101, F1-score: 0.100
# I: Precision: 0.117, Recall: 0.140, F1-score: 0.106
# J: Precision: 0.114, Recall: 0.103, F1-score: 0.087
# K: Precision: 0.129, Recall: 0.147, F1-score: 0.108
# L: Precision: 0.060, Recall: 0.088, F1-score: 0.055
# M: Precision: 0.424, Recall: 0.349, F1-score: 0.358
# O: Precision: 0.293, Recall: 0.277, F1-score: 0.264
# P: Precision: 0.407, Recall: 0.369, F1-score: 0.350
# Q: Precision: 0.114, Recall: 0.124, F1-score: 0.104
# R: Precision: 0.372, Recall: 0.422, F1-score: 0.360
# S: Precision: 0.395, Recall: 0.481, F1-score: 0.398
#
# Overall Accuracy: 0.309
# Processing features_phone_g.csv ...
# Average Train Accuracy: 0.379
# Average Test Accuracy:  0.315
#
# Average Confusion Matrix (Normalized by True Class):
# [[0.56097561 0.12093496 0.21138211 0.         0.         0.00101626
#   0.         0.         0.         0.         0.         0.00609756
#   0.0152439  0.03556911 0.04166667 0.         0.0050813  0.00203252]
#  [0.11892451 0.77042399 0.01758014 0.         0.         0.
#   0.         0.         0.         0.         0.00103413 0.
#   0.01447777 0.03826267 0.02481903 0.         0.01137539 0.00310238]
#  [0.13955929 0.04407135 0.57607555 0.00104932 0.         0.
#   0.00104932 0.         0.         0.         0.00314795 0.0115425
#   0.09443861 0.06610703 0.05351522 0.         0.00209864 0.00734523]
#  [0.         0.00410256 0.00307692 0.13333333 0.10153846 0.07589744
#   0.06358974 0.10871795 0.02769231 0.09230769 0.09333333 0.02871795
#   0.01230769 0.00923077 0.00307692 0.06461538 0.11076923 0.06769231]
#  [0.         0.         0.         0.05025641 0.33538462 0.03179487
#   0.05333333 0.04512821 0.01538462 0.07282051 0.09435897 0.00923077
#  [115 745  17   0   0   0   0   0   0   0   1   0  14  37  24   0  11   3]
#  [133  42 549   1   0   0   1   0   0   0   3  11  90  63  51   0   2   7]
#  [  0   4   3 130  99  74  62 106  27  90  91  28  12   9   3  63 108  66]
#  [  0   0   0  49 327  31  52  44  15  71  92   9   8  22  13  49  57 136]
#  [  0   0   2  51 118  93 104  66  46  84  62  36   3   0   0 144  94  34]
#  [ 13   9  13  44  53  33 432  48  21  24  22  14   4  10  27  33  93  85]
#  [  0   0   0  63  93  62  84 136  43 128 135  30   4   4   3  77  52  62]
#  [  0   0   0 104 114  64  68 114  50 113  94  32   3   9   1  72  45  70]
#  [  0   8   3  55  77  72  74 124  51 188  86  21   4   2   5  71  53  59]
#  [  1   0   4  73 134  61  46 121  32 114 136  48  13   6   2  91  52  42]
#  [ 14   0  13  87 103  67  88  91  47  98 115  18   7  10   6  84  47  60]
#  [ 14  20 137   0   0   0   2   0   0   0   1  19 518 190  52   0   0  25]
#  [  6  22  37   4  32   0  10   1   0   2   3   7 156 333 173   0   6 166]
#  [ 33  44  60   3  15  10  54   1   0   3   1   6 105 234 294   8  18  86]
#  [  0   5   5  86 122  99 105  85  32  89  83  10   2   7   1 164  43  15]
#  [ 13   5   5  85  53  37 160  40  28  14  49  18   5  28  29  44 306  56]
#  [  6   4  11  13 141  11  52  22  17  46  10   7  20  86  56  11  29 433]]
# Average Classification Report (per-class precision, recall, f1-score):
# A: Precision: 0.573, Recall: 0.566, F1-score: 0.547
# B: Precision: 0.723, Recall: 0.763, F1-score: 0.718
# C: Precision: 0.553, Recall: 0.578, F1-score: 0.529
# D: Precision: 0.163, Recall: 0.138, F1-score: 0.135
# E: Precision: 0.267, Recall: 0.349, F1-score: 0.275
# F: Precision: 0.135, Recall: 0.098, F1-score: 0.100
# G: Precision: 0.391, Recall: 0.433, F1-score: 0.358
# H: Precision: 0.121, Recall: 0.142, F1-score: 0.123
# I: Precision: 0.118, Recall: 0.052, F1-score: 0.060
# J: Precision: 0.218, Recall: 0.191, F1-score: 0.177
# K: Precision: 0.178, Recall: 0.141, F1-score: 0.134
# L: Precision: 0.042, Recall: 0.018, F1-score: 0.022
# M: Precision: 0.545, Recall: 0.536, F1-score: 0.511
# O: Precision: 0.335, Recall: 0.333, F1-score: 0.304
# P: Precision: 0.416, Recall: 0.312, F1-score: 0.323
# Q: Precision: 0.184, Recall: 0.175, F1-score: 0.150
# R: Precision: 0.332, Recall: 0.326, F1-score: 0.282
# S: Precision: 0.394, Recall: 0.454, F1-score: 0.393
#
# Overall Accuracy: 0.315

# %%
summary_df = pd.DataFrame(summary_results)
print("\n=== Summary of Train and Test Accuracies (Logistic Regression) ===")
print(summary_df.to_string(index=False))
# Out:
# === Summary of Train and Test Accuracies (Logistic Regression) ===
#              Dataset  Train Accuracy  Test Accuracy
# features_watch_a.csv        0.667505       0.648151
# features_watch_g.csv        0.642089       0.591309
# features_phone_a.csv        0.381445       0.308806
# features_phone_g.csv        0.379221       0.314871
